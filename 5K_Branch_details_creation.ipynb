# %% [markdown]
# <a href="https://colab.research.google.com/github/ssjsmith750/5k_Model_project/blob/main/5K_Branch_details_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# Define the locations and branches
locations = ['COIMBATORE', 'TRICHY', 'TIRUPUR', 'PONDICHERRY', 'TUTUCORIN',
             'HOSUR', 'CHENNAI', 'SALEM', 'MADURAI', 'POLLACHI', 'KARUR',
             'VELLORE']

branches = {
    'COIMBATORE': [
    "SARAVANAMPATTI", "ANNUR", "METTUPALAYAM", "THUDIYALUR", "KAVUNDAMPALAYAM",
    "VADAKOVAI", "VADAVALLI", "EDAYARPALAYAM", "KUNIYAMUTUR", "KOVAIPUDUR",
    "AVARAMPALAYAM", "GOLDWINS", "SUNDARAPURAM", "RAMANATHAPURAM", "ONIDIPUDUR",
    "SINGANALLUR", "SULUR", "HOPES", "MIRAJ CINIMAS", "FUNMALL", "CODISSIA",
    "BROOKFIELD", "NAVAKKARAI"
    ],

    'CHENNAI': [
    "ARUMBAKKAM", "VIVIRA MALL", "MAYAJAL", "MANTRA MALL", "THURAIPAKKAM",
    "GUDUVANCHERRY", "GRAND MALL", "ATHIPET", "PERUMBAKKAM", "PADUR",
    "AMBATTUR", "NUNGAMBAKKAM", "KANTHANCHAVADI", "PORUR",
    "PALLIKARANAI", "MADURAVAYIL"
    ],

    'TIRUPUR': [
    "AVINASHI", "PN ROAD", "PERUMANALLUR", "KANGAYAM", "AMMAPALAYAM",
    "PALLADAM - CBE ROAD", "TIRUPUR", "KARUMATHAMPATTI", "MANGALAM"
    ],

    'POLLACHI': [
    "KOZHINJAPARA", "UDUMALPET", "POLLACHI -1 PALLADAM ROAD",
    "POLLACHI -2 SANGAMPALAYAM", "POLLACHI -3 RTO OFFICE", "KINATHUKADAVU"
    ],

    'MADURAI': [
    "MADURAI PALNGANATHAM", "VISHAL DE MAL", "DINDIGUL",
    "DHARAPURAM", "PALANI", "MADURAI KK NAGAR", "MADURAI THIRU NAGAR",
    "THENI ANNANJI VILAKKU", "THENI PC PATTI", "OTTANCHATRAM"
    ],

    'TRICHY': [
    "TRICHY", "THANJAVUR", "KUMBAKONAM",
    "PUDUKOTTAI", "CUDDALORE", "VADALUR", "NEYVELI",
    "PANRUTI", "VIRUDHACHALAM", "PERAMBALUR", "GUNTUR"
    ],

    'PONDICHERRY': [
    "PONDICHERRY -1", "PONDICHERRY MOOLAKULAM", "THIRUBUVANAI",
    "THAVALAKUPPAM", "THIRUVANNAMALAI", "VELLORE", "PERUMAGAI"
    ],

    'TUTUCORIN': [
    "TENKASI", "TIRUNELVELI", "TIRUNELVELI UDAYARPATTI",
    "KOVILPATTI", "RAMNAD", "SIVAKASI"
    ],

    'SALEM': [
    "PERUNDURAI", "ERODE PALAYAPALAYAM", "ERODE NASIYANUR",
    "SALEM", "ELAMPILLAI", "SANGAGIRI", "TIRUCHENGODE",
    "NAMAKKAL", "PARAMATHI VELLUR", "KALLAKURUCHI", "KONDALAMPATTI- SALEM"
    ],

    'HOSUR': [
    "DHARMAPURI", "KRISHNAGIRI", "HOSUR -1", "HOSUR RING ROAD",
    "ATTIBELE", "ELEC TRONIC CITY", "TIRUPATTUR", "CHANDHAPURAM"
    ],

    'KARUR': [
    "KARUR"
    ],

    'VELLORE': [
    "VELLORE"]
}

# Create a DataFrame with 'locations' column
data = pd.DataFrame({'locations': locations * (1470 // len(locations))})

# Shuffle the locations randomly
data['locations'] = data['locations'].sample(frac=1).reset_index(drop=True)

# Map the branches to each location
data['branch'] = data['locations'].map(branches)

# Explode the 'branch' column to create the desired 1470 rows
data = data.explode('branch', ignore_index=True)

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#   locations           branch
# 0     HOSUR       DHARMAPURI
# 1     HOSUR      KRISHNAGIRI
# 2     HOSUR         HOSUR -1
# 3     HOSUR  HOSUR RING ROAD
# 4     HOSUR         ATTIBELE

# %%
data
# Out:
#       locations                 branch
# 0         HOSUR             DHARMAPURI
# 1         HOSUR            KRISHNAGIRI
# 2         HOSUR               HOSUR -1
# 3         HOSUR        HOSUR RING ROAD
# 4         HOSUR               ATTIBELE
# ...         ...                    ...
# 13293   MADURAI       MADURAI KK NAGAR
# 13294   MADURAI    MADURAI THIRU NAGAR
# 13295   MADURAI  THENI ANNANJI VILAKKU
# 13296   MADURAI         THENI PC PATTI
# 13297   MADURAI           OTTANCHATRAM
#
# [13298 rows x 2 columns]

# %%
import pandas as pd

# Assuming you have the DataFrame named 'df' with columns 'locations' and 'branch'
# df = ...

# Shuffle the rows randomly and select the first 1470 rows
selected_rows = data.sample(n=1470, random_state=42)

# Display the selected rows
print(selected_rows)
# Out:
#         locations               branch
# 12586     TIRUPUR  PALLADAM - CBE ROAD
# 10876     MADURAI        VISHAL DE MAL
# 5239      CHENNAI             AMBATTUR
# 8062   COIMBATORE                ANNUR
# 2366        SALEM             NAMAKKAL
# ...           ...                  ...
# 2673      CHENNAI              MAYAJAL
# 1954   COIMBATORE           BROOKFIELD
# 10351   TUTUCORIN             SIVAKASI
# 11161   TUTUCORIN             SIVAKASI
# 4789        SALEM     PARAMATHI VELLUR
#
# [1470 rows x 2 columns]

# %%
selected_rows.to_csv("5K_branch_details.csv")

# %%
HR_data = pd.read_csv("/content/HR_data_test.csv")

# %%
Branch_details = pd.read_csv("/content/5K_branch_details.csv")

# %%
Car_brands = pd.read_csv("/content/service car brands .csv")

# %%
HR_data
# Out:
#       Unnamed: 0 Attrition CF_age band CF_attrition label  Department  \
# 0              0        No     45 - 54  Current Employees  Operations
# 1              1        No     25 - 34  Current Employees          IT
# 2              2        No     45 - 54  Current Employees     Finance
# 3              3        No     25 - 34  Current Employees          IT
# 4              4        No     Over 55  Current Employees     Digital
# ...          ...       ...         ...                ...         ...
# 1465        1465        No     25 - 34  Current Employees  Operations
# 1466        1466        No     Over 55  Current Employees     Finance
# 1467        1467        No     35 - 44  Current Employees       Sales
# 1468        1468        No     Over 55  Current Employees       Sales
# 1469        1469        No     45 - 54  Current Employees     Finance
#
#           emp no  Employee Number  Gender                        Job Role  \
# ...

# %%
Branch_details
# Out:
#       Unnamed: 0   locations               branch
# 0          12586     TIRUPUR  PALLADAM - CBE ROAD
# 1          10876     MADURAI        VISHAL DE MAL
# 2           5239     CHENNAI             AMBATTUR
# 3           8062  COIMBATORE                ANNUR
# 4           2366       SALEM             NAMAKKAL
# ...          ...         ...                  ...
# 1465        2673     CHENNAI              MAYAJAL
# 1466        1954  COIMBATORE           BROOKFIELD
# 1467       10351   TUTUCORIN             SIVAKASI
# 1468       11161   TUTUCORIN             SIVAKASI
# 1469        4789       SALEM     PARAMATHI VELLUR
#
# [1470 rows x 3 columns]

# %%
Car_brands
# Out:
#       Unnamed: 0      Brands          Model
# 0            0.0        Tata      Nano Genx
# 1            1.0        Tata      Nano Genx
# 2            2.0        Tata      Nano Genx
# 3            3.0        Tata      Nano Genx
# 4            4.0        Tata      Nano Genx
# ...          ...         ...            ...
# 1427         NaN      Nissan        Magnite
# 1428         NaN      Nissan        Magnite
# 1429         NaN      Nissan        Magnite
# 1430         NaN  Volkswagen         Virtus
# 1431         NaN     Hyundai  Kona Electric
#
# [1432 rows x 3 columns]

# %%
columns_to_drop = ['Unnamed: 0', 'branch', 'locations']

# %%
HR_data = HR_data.drop(columns_to_drop, axis=1)

# %%
HR_data
# Out:
#      Attrition CF_age band CF_attrition label  Department      emp no  \
# 0           No     45 - 54  Current Employees  Operations   STAFF-595
# 1           No     25 - 34  Current Employees          IT   STAFF-808
# 2           No     45 - 54  Current Employees     Finance   STAFF-945
# 3           No     25 - 34  Current Employees          IT   STAFF-992
# 4           No     Over 55  Current Employees     Digital  STAFF-1071
# ...        ...         ...                ...         ...         ...
# 1465        No     25 - 34  Current Employees  Operations   STAFF-982
# 1466        No     Over 55  Current Employees     Finance  STAFF-1424
# 1467        No     35 - 44  Current Employees       Sales  STAFF-1740
# 1468        No     Over 55  Current Employees       Sales  STAFF-1938
# 1469        No     45 - 54  Current Employees     Finance  STAFF-1789
#
#       Employee Number  Gender                        Job Role  Age  \
# ...

# %%
import pandas as pd

# Assuming you have the 'HR_data' DataFrame and the 'Branch_details' DataFrame
# HR_data = ...
# Branch_details = ...

# Drop the 'Unnamed: 0' column from 'Branch_details' DataFrame
Branch_details = Branch_details.drop(columns='Unnamed: 0')

# Merge the 'Branch_details' DataFrame with the 'HR_data' DataFrame based on index
merged_data = HR_data.merge(Branch_details, left_index=True, right_index=True)

# Display the first few rows of the merged DataFrame
print(merged_data.head())
# Out:
#   Attrition CF_age band CF_attrition label  Department      emp no  \
# 0        No     45 - 54  Current Employees  Operations   STAFF-595
# 1        No     25 - 34  Current Employees          IT   STAFF-808
# 2        No     45 - 54  Current Employees     Finance   STAFF-945
# 3        No     25 - 34  Current Employees          IT   STAFF-992
# 4        No     Over 55  Current Employees     Digital  STAFF-1071
#
#    Employee Number  Gender               Job Role  Age  CF_current Employee  \
# 0              595  Female     Operations Manager   48                    1
# 1              808  Female             IT Manager   34                    1
# 2              945    Male        Finance Manager   48                    1
# 3              992    Male  Network Administrator   33                    1
# 4             1071  Female          Web Developer   56                    1
#
#    ...  Standard Hours  Total Working Years  Work Life Balance  \
# ...

# %%
merged_data
# Out:
#      Attrition CF_age band CF_attrition label  Department      emp no  \
# 0           No     45 - 54  Current Employees  Operations   STAFF-595
# 1           No     25 - 34  Current Employees          IT   STAFF-808
# 2           No     45 - 54  Current Employees     Finance   STAFF-945
# 3           No     25 - 34  Current Employees          IT   STAFF-992
# 4           No     Over 55  Current Employees     Digital  STAFF-1071
# ...        ...         ...                ...         ...         ...
# 1465        No     25 - 34  Current Employees  Operations   STAFF-982
# 1466        No     Over 55  Current Employees     Finance  STAFF-1424
# 1467        No     35 - 44  Current Employees       Sales  STAFF-1740
# 1468        No     Over 55  Current Employees       Sales  STAFF-1938
# 1469        No     45 - 54  Current Employees     Finance  STAFF-1789
#
#       Employee Number  Gender                        Job Role  Age  \
# ...

# %%
import pandas as pd

# Assuming you have the 'HR_data' DataFrame and the 'Branch_details' DataFrame
# HR_data = ...
# Branch_details = ...

# Drop the 'Unnamed: 0' column from 'Branch_details' DataFrame
Car_brands = Car_brands.drop(columns='Unnamed: 0')

# Merge the 'Branch_details' DataFrame with the 'HR_data' DataFrame based on index
merged_data = merged_data.merge(Car_brands, left_index=True, right_index=True)

# Display the first few rows of the merged DataFrame
print(merged_data.head())
# Out:
#   Attrition CF_age band CF_attrition label  Department      emp no  \
# 0        No     45 - 54  Current Employees  Operations   STAFF-595
# 1        No     25 - 34  Current Employees          IT   STAFF-808
# 2        No     45 - 54  Current Employees     Finance   STAFF-945
# 3        No     25 - 34  Current Employees          IT   STAFF-992
# 4        No     Over 55  Current Employees     Digital  STAFF-1071
#
#    Employee Number  Gender               Job Role  Age  CF_current Employee  \
# 0              595  Female     Operations Manager   48                    1
# 1              808  Female             IT Manager   34                    1
# 2              945    Male        Finance Manager   48                    1
# 3              992    Male  Network Administrator   33                    1
# 4             1071  Female          Web Developer   56                    1
#
#    ...  Work Life Balance  Years At Company  Years In Current Role  \
# ...

# %%
merged_data
# Out:
#      Attrition CF_age band CF_attrition label  Department      emp no  \
# 0           No     45 - 54  Current Employees  Operations   STAFF-595
# 1           No     25 - 34  Current Employees          IT   STAFF-808
# 2           No     45 - 54  Current Employees     Finance   STAFF-945
# 3           No     25 - 34  Current Employees          IT   STAFF-992
# 4           No     Over 55  Current Employees     Digital  STAFF-1071
# ...        ...         ...                ...         ...         ...
# 1427       Yes     35 - 44       Ex-Employees   Marketing  STAFF-1210
# 1428        No     45 - 54  Current Employees          HR  STAFF-1217
# 1429       Yes     45 - 54       Ex-Employees  Operations  STAFF-1277
# 1430        No     35 - 44  Current Employees          HR  STAFF-1291
# 1431        No     35 - 44  Current Employees     Finance  STAFF-1294
#
#       Employee Number  Gender                  Job Role  Age  \
# 0                 595  Female        Operations Manager   48
# ...

# %%
merged_data.to_csv("5K_Brand_details.csv")

# %% [markdown]
# # **21/07/2023**  Customer details

# %%
import pandas as pd
import numpy as np

# %%
customer_data = pd.read_csv("/content/Customer details.csv")

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
import pandas as pd

# Assuming you have your dataset loaded into 'df' DataFrame

# Replace 'Attrited Customer' with 'New Customer' in the 'Attrition_Flag' column
customer_data['Attrition_Flag'] = customer_data['Attrition_Flag'].replace('Attrited Customer', 'New Customer')

# Display the updated count of each unique value
attrition_count = customer_data['Attrition_Flag'].value_counts()
print(attrition_count)
# Out:
# Existing Customer    8500
# New Customer         1627
# Name: Attrition_Flag, dtype: int64

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233       New Customer            41      M                2
# 10124  716506083       New Customer            44      F                1
# 10125  717406983       New Customer            30      M                2
# 10126  714337233       New Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
customer_data.Card_Category.unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
import pandas as pd

# Assuming you have your dataset loaded into 'df' DataFrame

# Create a mapping dictionary to replace values in 'Card_Category'
card_category_mapping = {
    'Blue': 'Credit Card',
    'Gold': 'Debit Card',
    'Silver': 'Digital Payment',
    'Platinum': 'Cash'
}

# Replace values in the 'Card_Category' column using the mapping dictionary
customer_data['Card_Category'] = customer_data['Card_Category'].replace(card_category_mapping)

# Display the updated count of each unique value in 'Card_Category'
card_category_count = customer_data['Card_Category'].value_counts()
print(card_category_count)
# Out:
# Credit Card        9436
# Digital Payment     555
# Debit Card          116
# Cash                 20
# Name: Card_Category, dtype: int64

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233       New Customer            41      M                2
# 10124  716506083       New Customer            44      F                1
# 10125  717406983       New Customer            30      M                2
# 10126  714337233       New Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category    Card_Category  \
# ...

# %%
customer_data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
columns_to_drop = ['Dependent_count','Education_Level','Marital_Status','Income_Category','Credit_Limit','Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
customer_data = customer_data.drop(columns_to_drop,axis=1)

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender    Card_Category  \
# 0      768805383  Existing Customer            45      M      Credit Card
# 1      818770008  Existing Customer            49      F      Credit Card
# 2      713982108  Existing Customer            51      M      Credit Card
# 3      769911858  Existing Customer            40      F      Credit Card
# 4      709106358  Existing Customer            40      M      Credit Card
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M      Credit Card
# 10123  710638233       New Customer            41      M      Credit Card
# 10124  716506083       New Customer            44      F      Credit Card
# 10125  717406983       New Customer            30      M      Credit Card
# 10126  714337233       New Customer            43      F  Digital Payment
#
#        Months_on_book
# 0                  39
# 1                  44
# ...

# %%
import pandas as pd
import numpy as np

# Assuming you have your 'customer_data' DataFrame loaded
# customer_data = ...

# Define the 'locations' and 'branches' data
locations = ['COIMBATORE', 'TRICHY', 'TIRUPUR', 'PONDICHERRY', 'TUTUCORIN',
             'HOSUR', 'CHENNAI', 'SALEM', 'MADURAI', 'POLLACHI', 'KARUR',
             'VELLORE']

branches = ['ARUMBAKKAM', 'VIVIRA MALL', 'MAYAJAL', 'MANTRA MALL', 'THURAIPAKKAM', 'GUDUVANCHERRY',
    'GRAND MALL', 'ATHIPET', 'AVINASHI', 'PN ROAD', 'NAVAKKARAI', 'KOZHINJAPARA', 'UDUMALPET',
    'MADURAI PALNGANATHAM', 'VISHAL DE MAL', 'HOPES', 'MIRAJ CINIMAS', 'FUNMALL', 'CODISSIA',
    'BROOKFIELD', 'PERUMBAKKAM', 'PADUR', 'AMBATTUR', 'NUNGAMBAKKAM', 'KANTHANCHAVADI',
    'PORUR', 'PALLIKARANAI', 'PERUMANALLUR', 'KANGAYAM', 'AMMAPALAYAM', 'PALLADAM - CBE ROAD',
    'TIRUPUR', 'KARUR', 'KARUMATHAMPATTI', 'MANGALAM', 'PONDICHERRY -1', 'PONDICHERRY MOOLAKULAM',
    'THIRUBUVANAI', 'THAVALAKUPPAM', 'THIRUVANNAMALAI', 'VELLORE', 'PERUMAGAI', 'POLLACHI -1 PALLADAM ROAD',
    'POLLACHI -2 SANGAMPALAYAM', 'POLLACHI -3 RTO OFFICE', 'KINATHUKADAVU', 'TRICHY', 'THANJAVUR',
    'KUMBAKONAM', 'PUDUKOTTAI', 'CUDDALORE', 'VADALUR', 'NEYVELI', 'PANRUTI', 'VIRUDHACHALAM',
    'PERAMBALUR', 'DINDIGUL', 'DHARAPURAM', 'PALANI', 'MADURAI KK NAGAR', 'MADURAI THIRU NAGAR',
    'THENI ANNANJI VILAKKU', 'THENI PC PATTI', 'OTTANCHATRAM', 'DHARMAPURI', 'KRISHNAGIRI',
    'HOSUR -1', 'HOSUR RING ROAD', 'ATTIBELE', 'ELEC TRONIC CITY', 'TIRUPATTUR', 'CHANDHAPURAM',
    'TENKASI', 'TIRUNELVELI', 'TIRUNELVELI UDAYARPATTI', 'KOVILPATTI', 'RAMNAD', 'SIVAKASI',
    'PERUNDURAI', 'ERODE PALAYAPALAYAM', 'ERODE NASIYANUR', 'SALEM', 'ELAMPILLAI', 'SANGAGIRI',
    'TIRUCHENGODE', 'NAMAKKAL', 'PARAMATHI VELLUR', 'KALLAKURUCHI', 'KONDALAMPATTI- SALEM',
    'SARAVANAMPATTI', 'ANNUR', 'METTUPALAYAM', 'THUDIYALUR', 'KAVUNDAMPALAYAM', 'VADAKOVAI',
    'VADAVALLI', 'EDAYARPALAYAM', 'KUNIYAMUTUR', 'KOVAIPUDUR', 'AVARAMPALAYAM', 'GOLDWINS',
    'SUNDARAPURAM', 'RAMANATHAPURAM', 'ONIDIPUDUR', 'SINGANALLUR', 'SULUR', 'VELLALORE',
    'MADURAVAYIL', 'GUNTUR']

# Shuffle the 'locations' and 'branches' values
shuffled_locations = np.random.choice(locations, size=len(customer_data))
shuffled_branches = np.random.choice(branches, size=len(customer_data))

# Add the shuffled 'locations' and 'branches' columns to the 'customer_data' DataFrame
customer_data['location'] = shuffled_locations
customer_data['branch'] = shuffled_branches

# Display the first few rows of the updated DataFrame
print(customer_data.head())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender Card_Category  \
# 0  768805383  Existing Customer            45      M   Credit Card
# 1  818770008  Existing Customer            49      F   Credit Card
# 2  713982108  Existing Customer            51      M   Credit Card
# 3  769911858  Existing Customer            40      F   Credit Card
# 4  709106358  Existing Customer            40      M   Credit Card
#
#    Months_on_book  location                     branch
# 0              39    TRICHY                      SULUR
# 1              44   CHENNAI            THIRUVANNAMALAI
# 2              36     SALEM  POLLACHI -1 PALLADAM ROAD
# 3              34     HOSUR       KONDALAMPATTI- SALEM
# 4              21  POLLACHI       MADURAI PALNGANATHAM

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender    Card_Category  \
# 0      768805383  Existing Customer            45      M      Credit Card
# 1      818770008  Existing Customer            49      F      Credit Card
# 2      713982108  Existing Customer            51      M      Credit Card
# 3      769911858  Existing Customer            40      F      Credit Card
# 4      709106358  Existing Customer            40      M      Credit Card
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M      Credit Card
# 10123  710638233       New Customer            41      M      Credit Card
# 10124  716506083       New Customer            44      F      Credit Card
# 10125  717406983       New Customer            30      M      Credit Card
# 10126  714337233       New Customer            43      F  Digital Payment
#
#        Months_on_book    location                     branch
# ...

# %%
import pandas as pd
import random

# Define the locations and branches
locations = ['COIMBATORE', 'TRICHY', 'TIRUPUR', 'PONDICHERRY', 'TUTUCORIN',
             'HOSUR', 'CHENNAI', 'SALEM', 'MADURAI', 'POLLACHI', 'KARUR',
             'VELLORE']

branches = {
    'COIMBATORE': [
    "SARAVANAMPATTI", "ANNUR", "METTUPALAYAM", "THUDIYALUR", "KAVUNDAMPALAYAM",
    "VADAKOVAI", "VADAVALLI", "EDAYARPALAYAM", "KUNIYAMUTUR", "KOVAIPUDUR",
    "AVARAMPALAYAM", "GOLDWINS", "SUNDARAPURAM", "RAMANATHAPURAM", "ONIDIPUDUR",
    "SINGANALLUR", "SULUR", "HOPES", "MIRAJ CINIMAS", "FUNMALL", "CODISSIA",
    "BROOKFIELD", "NAVAKKARAI"
    ],

    'CHENNAI': [
    "ARUMBAKKAM", "VIVIRA MALL", "MAYAJAL", "MANTRA MALL", "THURAIPAKKAM",
    "GUDUVANCHERRY", "GRAND MALL", "ATHIPET", "PERUMBAKKAM", "PADUR",
    "AMBATTUR", "NUNGAMBAKKAM", "KANTHANCHAVADI", "PORUR",
    "PALLIKARANAI", "MADURAVAYIL"
    ],

    'TIRUPUR': [
    "AVINASHI", "PN ROAD", "PERUMANALLUR", "KANGAYAM", "AMMAPALAYAM",
    "PALLADAM - CBE ROAD", "TIRUPUR", "KARUMATHAMPATTI", "MANGALAM"
    ],

    'POLLACHI': [
    "KOZHINJAPARA", "UDUMALPET", "POLLACHI -1 PALLADAM ROAD",
    "POLLACHI -2 SANGAMPALAYAM", "POLLACHI -3 RTO OFFICE", "KINATHUKADAVU"
    ],

    'MADURAI': [
    "MADURAI PALNGANATHAM", "VISHAL DE MAL", "DINDIGUL",
    "DHARAPURAM", "PALANI", "MADURAI KK NAGAR", "MADURAI THIRU NAGAR",
    "THENI ANNANJI VILAKKU", "THENI PC PATTI", "OTTANCHATRAM"
    ],

    'TRICHY': [
    "TRICHY", "THANJAVUR", "KUMBAKONAM",
    "PUDUKOTTAI", "CUDDALORE", "VADALUR", "NEYVELI",
    "PANRUTI", "VIRUDHACHALAM", "PERAMBALUR", "GUNTUR"
    ],

    'PONDICHERRY': [
    "PONDICHERRY -1", "PONDICHERRY MOOLAKULAM", "THIRUBUVANAI",
    "THAVALAKUPPAM", "THIRUVANNAMALAI", "VELLORE", "PERUMAGAI"
    ],

    'TUTUCORIN': [
    "TENKASI", "TIRUNELVELI", "TIRUNELVELI UDAYARPATTI",
    "KOVILPATTI", "RAMNAD", "SIVAKASI"
    ],

    'SALEM': [
    "PERUNDURAI", "ERODE PALAYAPALAYAM", "ERODE NASIYANUR",
    "SALEM", "ELAMPILLAI", "SANGAGIRI", "TIRUCHENGODE",
    "NAMAKKAL", "PARAMATHI VELLUR", "KALLAKURUCHI", "KONDALAMPATTI- SALEM"
    ],

    'HOSUR': [
    "DHARMAPURI", "KRISHNAGIRI", "HOSUR -1", "HOSUR RING ROAD",
    "ATTIBELE", "ELEC TRONIC CITY", "TIRUPATTUR", "CHANDHAPURAM"
    ],

    'KARUR': [
    "KARUR"
    ],

    'VELLORE': [
    "VELLORE"]
}

# Create a DataFrame with 'locations' column
location_data = pd.DataFrame({'locations': locations * (10127 // len(locations))})

# Shuffle the locations randomly
location_data['locations'] = location_data['locations'].sample(frac=1).reset_index(drop=True)

# Map the branches to each location
location_data['branch'] = location_data['locations'].map(branches)

# Explode the 'branch' column to create the desired 1470 rows
location_data = location_data.explode('branch', ignore_index=True)

# Display the first few rows of the DataFrame
print(location_data.head())
# Out:
#   locations                branch
# 0   MADURAI  MADURAI PALNGANATHAM
# 1   MADURAI         VISHAL DE MAL
# 2   MADURAI              DINDIGUL
# 3   MADURAI            DHARAPURAM
# 4   MADURAI                PALANI

# %%
location_data
# Out:
#       locations                branch
# 0       MADURAI  MADURAI PALNGANATHAM
# 1       MADURAI         VISHAL DE MAL
# 2       MADURAI              DINDIGUL
# 3       MADURAI            DHARAPURAM
# 4       MADURAI                PALANI
# ...         ...                   ...
# 91882     HOSUR       HOSUR RING ROAD
# 91883     HOSUR              ATTIBELE
# 91884     HOSUR      ELEC TRONIC CITY
# 91885     HOSUR            TIRUPATTUR
# 91886     HOSUR          CHANDHAPURAM
#
# [91887 rows x 2 columns]

# %%
columns_to_drop = [ 'branch', 'location']
customer_data = customer_data.drop(columns_to_drop,axis=1)

# %%
import pandas as pd

# Assuming you have the 'HR_data' DataFrame and the 'Branch_details' DataFrame
# HR_data = ...
# Branch_details = ...

# Drop the 'Unnamed: 0' column from 'Branch_details' DataFrame
#Branch_details = Branch_details.drop(columns='locations','branch',axis=1)

# Merge the 'Branch_details' DataFrame with the 'HR_data' DataFrame based on index
merged_data = customer_data.merge(location_data, left_index=True, right_index=True)

# Display the first few rows of the merged DataFrame
print(merged_data.head())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender Card_Category  \
# 0  768805383  Existing Customer            45      M   Credit Card
# 1  818770008  Existing Customer            49      F   Credit Card
# 2  713982108  Existing Customer            51      M   Credit Card
# 3  769911858  Existing Customer            40      F   Credit Card
# 4  709106358  Existing Customer            40      M   Credit Card
#
#    Months_on_book locations                branch
# 0              39   MADURAI  MADURAI PALNGANATHAM
# 1              44   MADURAI         VISHAL DE MAL
# 2              36   MADURAI              DINDIGUL
# 3              34   MADURAI            DHARAPURAM
# 4              21   MADURAI                PALANI

# %%
merged_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender    Card_Category  \
# 0      768805383  Existing Customer            45      M      Credit Card
# 1      818770008  Existing Customer            49      F      Credit Card
# 2      713982108  Existing Customer            51      M      Credit Card
# 3      769911858  Existing Customer            40      F      Credit Card
# 4      709106358  Existing Customer            40      M      Credit Card
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M      Credit Card
# 10123  710638233       New Customer            41      M      Credit Card
# 10124  716506083       New Customer            44      F      Credit Card
# 10125  717406983       New Customer            30      M      Credit Card
# 10126  714337233       New Customer            43      F  Digital Payment
#
#        Months_on_book locations                branch
# ...

# %%
merged_data = merged_data.to_csv("5k_customer_details.csv")

# %%
car_brands = pd.read_csv("/content/service car brands .csv")

# %%
customer_details =  pd.read_csv("/content/5k_customer_details.csv")

# %%
car_brands
# Out:
#       Unnamed: 0      Brands          Model
# 0            0.0        Tata      Nano Genx
# 1            1.0        Tata      Nano Genx
# 2            2.0        Tata      Nano Genx
# 3            3.0        Tata      Nano Genx
# 4            4.0        Tata      Nano Genx
# ...          ...         ...            ...
# 1427         NaN      Nissan        Magnite
# 1428         NaN      Nissan        Magnite
# 1429         NaN      Nissan        Magnite
# 1430         NaN  Volkswagen         Virtus
# 1431         NaN     Hyundai  Kona Electric
#
# [1432 rows x 3 columns]

# %%
columns_to_drop = ['Unnamed: 0']
car_brands = car_brands.drop(columns_to_drop,axis=1)

# %%
import pandas as pd

# Assuming you have your 'car_brands' DataFrame loaded
# car_brands = ...

# Number of times to repeat the DataFrame to reach 10127 rows
desired_rows = 10127

# Calculate the number of repetitions needed
repetitions = desired_rows // len(car_brands) + 1

# Concatenate the DataFrame with itself
expanded_car_brands = pd.concat([car_brands] * repetitions, ignore_index=True)

# Keep only the first 10127 rows
expanded_car_brands = expanded_car_brands[:desired_rows]

# Display the first few rows of the expanded DataFrame
print(expanded_car_brands.head())
# Out:
#   Brands      Model
# 0   Tata  Nano Genx
# 1   Tata  Nano Genx
# 2   Tata  Nano Genx
# 3   Tata  Nano Genx
# 4   Tata  Nano Genx

# %%
expanded_car_brands
# Out:
#        Brands         Model
# 0        Tata     Nano Genx
# 1        Tata     Nano Genx
# 2        Tata     Nano Genx
# 3        Tata     Nano Genx
# 4        Tata     Nano Genx
# ...       ...           ...
# 10122  Toyota    Etios Liva
# 10123  Toyota    Etios Liva
# 10124  Toyota    Etios Liva
# 10125  Nissan  Micra Active
# 10126  Nissan  Micra Active
#
# [10127 rows x 2 columns]

# %%
import pandas as pd

# Assuming you have the 'HR_data' DataFrame and the 'Branch_details' DataFrame
# HR_data = ...
# Branch_details = ...

# Drop the 'Unnamed: 0' column from 'Branch_details' DataFrame
#Branch_details = Branch_details.drop(columns='locations','branch',axis=1)

# Merge the 'Branch_details' DataFrame with the 'HR_data' DataFrame based on index
merged_5k_data = customer_details.merge(expanded_car_brands, left_index=True, right_index=True)

# Display the first few rows of the merged DataFrame
print(merged_5k_data.head())
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#   Card_Category  Months_on_book locations                branch Brands  \
# 0   Credit Card              39   MADURAI  MADURAI PALNGANATHAM   Tata
# 1   Credit Card              44   MADURAI         VISHAL DE MAL   Tata
# 2   Credit Card              36   MADURAI              DINDIGUL   Tata
# 3   Credit Card              34   MADURAI            DHARAPURAM   Tata
# 4   Credit Card              21   MADURAI                PALANI   Tata
#
#        Model
# 0  Nano Genx
# 1  Nano Genx
# 2  Nano Genx
# 3  Nano Genx
# 4  Nano Genx

# %%
merged_5k_data
# Out:
#        Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0               0  768805383  Existing Customer            45      M
# 1               1  818770008  Existing Customer            49      F
# 2               2  713982108  Existing Customer            51      M
# 3               3  769911858  Existing Customer            40      F
# 4               4  709106358  Existing Customer            40      M
# ...           ...        ...                ...           ...    ...
# 10122       10122  772366833  Existing Customer            50      M
# 10123       10123  710638233       New Customer            41      M
# 10124       10124  716506083       New Customer            44      F
# 10125       10125  717406983       New Customer            30      M
# 10126       10126  714337233       New Customer            43      F
#
#          Card_Category  Months_on_book locations                branch  \
# ...

# %%
import pandas as pd
import random

# Assuming your dataset is loaded into a DataFrame named 'merged_5k_data'
# You can load your dataset using pd.read_csv() or any other appropriate method.

# Create a new column 'customer_visiting_count' and set the initial value to 0
merged_5k_data['customer_visiting_count'] = 0

# Generate random values between 1 and 15 for Existing Customers
existing_customer_indices = merged_5k_data[merged_5k_data['Attrition_Flag'] == 'Existing Customer'].index
for index in existing_customer_indices:
    merged_5k_data.at[index, 'customer_visiting_count'] = random.randint(1, 15)

# Display the first few rows of the updated DataFrame
print(merged_5k_data.head())

# If you are satisfied with the changes, you can save the DataFrame back to a CSV file or any other format.
# For example:
# merged_5k_data.to_csv('updated_dataset.csv', index=False)
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#   Card_Category  Months_on_book locations                branch Brands  \
# 0   Credit Card              39   MADURAI  MADURAI PALNGANATHAM   Tata
# 1   Credit Card              44   MADURAI         VISHAL DE MAL   Tata
# 2   Credit Card              36   MADURAI              DINDIGUL   Tata
# 3   Credit Card              34   MADURAI            DHARAPURAM   Tata
# 4   Credit Card              21   MADURAI                PALANI   Tata
#
#        Model  customer_visiting_count
# 0  Nano Genx                        4
# 1  Nano Genx                        2
# ...

# %% [markdown]
# # **Customer_catagory**

# %%
import pandas as pd
import numpy as np

# Assuming you have your dataset loaded into a DataFrame named 'your_dataset'
# your_dataset = ...

# Number of rows in your dataset
num_rows = len(merged_5k_data)

# Define the customer categories and their respective counts
customer_categories = ['Blue', 'Silver', 'Gold', 'Premium']
category_counts = [int(num_rows * 0.6), int(num_rows * 0.2), int(num_rows * 0.15), int(num_rows * 0.05)]

# Ensure the total count does not exceed the number of rows
total_count = sum(category_counts)
if total_count > num_rows:
    category_counts[-1] -= (total_count - num_rows)

# Generate counts for each category based on the category counts
counts = np.random.multinomial(num_rows, [count / num_rows for count in category_counts])

# Calculate the probability weights for each category
prob_weights = counts / num_rows

# Generate random shuffled Customer_category values based on the category counts
customer_category_values = np.random.choice(customer_categories, size=num_rows, replace=True, p=prob_weights)

# Add the 'Customer_category' column to your dataset
merged_5k_data['Customer_category'] = customer_category_values

# Display the first few rows of the updated DataFrame
print(merged_5k_data.head())
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#   Card_Category  Months_on_book locations                branch Brands  \
# 0   Credit Card              39   MADURAI  MADURAI PALNGANATHAM   Tata
# 1   Credit Card              44   MADURAI         VISHAL DE MAL   Tata
# 2   Credit Card              36   MADURAI              DINDIGUL   Tata
# 3   Credit Card              34   MADURAI            DHARAPURAM   Tata
# 4   Credit Card              21   MADURAI                PALANI   Tata
#
#        Model  customer_visiting_count Customer_category
# 0  Nano Genx                        4              Blue
# ...

# %%
merged_5k_data
# Out:
#        Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0               0  768805383  Existing Customer            45      M
# 1               1  818770008  Existing Customer            49      F
# 2               2  713982108  Existing Customer            51      M
# 3               3  769911858  Existing Customer            40      F
# 4               4  709106358  Existing Customer            40      M
# ...           ...        ...                ...           ...    ...
# 10122       10122  772366833  Existing Customer            50      M
# 10123       10123  710638233       New Customer            41      M
# 10124       10124  716506083       New Customer            44      F
# 10125       10125  717406983       New Customer            30      M
# 10126       10126  714337233       New Customer            43      F
#
#          Card_Category  Months_on_book locations                branch  \
# ...

# %%
import pandas as pd
import numpy as np

# Assuming you have your dataset loaded into a DataFrame named 'your_dataset'
# your_dataset = ...

# Number of rows in your dataset
num_rows = len(merged_5k_data)

# List of days of the week in the desired order of preference
days_of_week = ['Sunday', 'Saturday', 'Friday', 'Thursday', 'Wednesday', 'Tuesday', 'Monday']

# Calculate the number of visits for each day based on your preference
# Sunday has the highest count (e.g., 30%), Saturday (e.g., 25%), Friday (e.g., 20%), Monday (e.g., 5%)
visit_percentages = [0.3, 0.25, 0.2, 0.05]

# Calculate the number of visits for each day
total_visits = int(num_rows * 0.9)  # 90% of total rows (to ensure enough rows for the top 4 days)
visit_counts = [int(total_visits * percentage) for percentage in visit_percentages]

# Calculate the remaining number of rows for Tuesday, Wednesday, and Thursday
remaining_rows = num_rows - sum(visit_counts)

# Assign the remaining rows uniformly across Tuesday, Wednesday, and Thursday
remaining_counts = remaining_rows // 3
visit_counts.extend([remaining_counts, remaining_counts, remaining_counts])

# Shuffle the visit counts based on the days_of_week order
np.random.shuffle(visit_counts)

# Create a dictionary to map days of the week to visit counts
visit_count_mapping = dict(zip(days_of_week, visit_counts))

# Generate random shuffled Visiting_day values based on the visit counts
visiting_day_values = np.random.choice(days_of_week, size=num_rows, replace=True, p=[visit_count_mapping[day] / num_rows for day in days_of_week])

# Add the 'Visiting_day' column to your dataset
merged_5k_data['Visiting_day'] = visiting_day_values

# Display the first few rows of the updated DataFrame
print(merged_5k_data.head())
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#   Card_Category  Months_on_book locations                branch Brands  \
# 0   Credit Card              39   MADURAI  MADURAI PALNGANATHAM   Tata
# 1   Credit Card              44   MADURAI         VISHAL DE MAL   Tata
# 2   Credit Card              36   MADURAI              DINDIGUL   Tata
# 3   Credit Card              34   MADURAI            DHARAPURAM   Tata
# 4   Credit Card              21   MADURAI                PALANI   Tata
#
#        Model  customer_visiting_count Customer_category Visiting_day
# 0  Nano Genx                        4              Blue     Saturday
# ...

# %%
day_count = merged_5k_data['Visiting_day'].value_counts()
day_count
# Out:
# Friday       2793
# Sunday       2257
# Saturday     1880
# Thursday      948
# Wednesday     917
# Monday        868
# Tuesday       464
# Name: Visiting_day, dtype: int64

# %% [markdown]
# # **Customer_Review**

# %%
import pandas as pd
import numpy as np

# Assuming you have your dataset loaded into a DataFrame named 'your_dataset'
# your_dataset = ...

# Number of rows in your dataset
num_rows = len(merged_5k_data)

# Define the customer categories and their respective counts
customer_Review = ['Good', 'Excellent', 'Fair', 'Satisfactory']
category_counts = [int(num_rows * 0.6), int(num_rows * 0.2), int(num_rows * 0.15), int(num_rows * 0.05)]

# Ensure the total count does not exceed the number of rows
total_count = sum(category_counts)
if total_count > num_rows:
    category_counts[-1] -= (total_count - num_rows)

# Generate counts for each category based on the category counts
counts = np.random.multinomial(num_rows, [count / num_rows for count in category_counts])

# Calculate the probability weights for each category
prob_weights = counts / num_rows

# Generate random shuffled Customer_category values based on the category counts
Customer_Review_values = np.random.choice(customer_Review, size=num_rows, replace=True, p=prob_weights)

# Add the 'Customer_category' column to your dataset
merged_5k_data['Customer_Review'] = Customer_Review_values

# Display the first few rows of the updated DataFrame
print(merged_5k_data.head())
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#   Card_Category  Months_on_book locations                branch Brands  \
# 0   Credit Card              39   MADURAI  MADURAI PALNGANATHAM   Tata
# 1   Credit Card              44   MADURAI         VISHAL DE MAL   Tata
# 2   Credit Card              36   MADURAI              DINDIGUL   Tata
# 3   Credit Card              34   MADURAI            DHARAPURAM   Tata
# 4   Credit Card              21   MADURAI                PALANI   Tata
#
#        Model  customer_visiting_count Customer_category Visiting_day  \
# 0  Nano Genx                        4              Blue     Saturday
# ...

# %%
merged_5k_data
# Out:
#        Unnamed: 0  CLIENTNUM      Customer_Type  Customer_Age Gender  \
# 0               0  768805383  Existing Customer            45      M
# 1               1  818770008  Existing Customer            49      F
# 2               2  713982108  Existing Customer            51      M
# 3               3  769911858  Existing Customer            40      F
# 4               4  709106358  Existing Customer            40      M
# ...           ...        ...                ...           ...    ...
# 10122       10122  772366833  Existing Customer            50      M
# 10123       10123  710638233       New Customer            41      M
# 10124       10124  716506083       New Customer            44      F
# 10125       10125  717406983       New Customer            30      M
# 10126       10126  714337233       New Customer            43      F
#
#          Card_Category  Months_on_book locations                branch  \
# ...

# %%
merged_5k_data.rename(columns={'Attrition_Flag': 'Customer_Type'}, inplace=True)

# %%
columns_to_drop = ['Unnamed: 0']
merged_5k_data = merged_5k_data.drop(columns_to_drop,axis=1)

# %%
merged_5k_data.to_csv("5K_Customer_details_Final.csv")
